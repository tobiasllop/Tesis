# %% [markdown]
# <a href="https://colab.research.google.com/github/tobiasllop/Tesis/blob/main/Tesis_v5_Grupos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="background-color: #1a3e59; padding: 20px; border-radius: 10px;">
# <h1 style="color: #ffffff; margin: 0; text-align: center;">Tesis: Análisis MCA de Deudores BCRA vs Padrón ARCA 🚀</h1>
# <p style="color: #d1e8ff; text-align: center; margin-top: 10px; font-size: 1.1em;">Fase 2: Reducción de Dimensionalidad, Clustering de Entidades Financieras y Perfiles Demográficos.</p>
# </div>

# %% [markdown]
# ## <span style="color: #2b7a78;">1. Instalación de Librerías y Configuración Inicial ⚙️</span>

# %%
# !pip install prince plotly polars pandas numpy kaleido
import polars as pl
import pandas as pd
import numpy as np
import plotly.express as px
import prince
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting prince
#   Downloading prince-0.19.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.35.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Collecting kaleido
#   Downloading kaleido-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: scikit-learn>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from prince) (1.6.1)
# Requirement already satisfied: altair>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from prince) (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.1)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars) (1.35.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Collecting choreographer>=1.3.0 (from kaleido)
#   Downloading choreographer-1.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido) (3.11.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair>=5.0.0->prince) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair>=5.0.0->prince) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair>=5.0.0->prince) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from altair>=5.0.0->prince) (4.15.0)
# Requirement already satisfied: platformdirs>=4.3.6 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido) (4.9.6)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.3.0->kaleido) (4.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.1->prince) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.1->prince) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5.1->prince) (3.6.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair>=5.0.0->prince) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair>=5.0.0->prince) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair>=5.0.0->prince) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair>=5.0.0->prince) (0.30.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair>=5.0.0->prince) (3.0.3)
# Downloading prince-0.19.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 3.7 MB/s eta 0:00:00
# Downloading kaleido-1.3.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 1.8 MB/s eta 0:00:00
# Downloading choreographer-1.3.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 1.6 MB/s eta 0:00:00
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Installing collected packages: logistro, choreographer, kaleido, prince
# Successfully installed choreographer-1.3.0 kaleido-1.3.0 logistro-2.0.1 prince-0.19.0
# Mounted at /content/drive

# %% [markdown]
# ## <span style="color: #2b7a78;">2. Carga de Bases de Datos y Limpieza Poblacional 🧹</span>
# En esta sección cargamos la Central de Deudores del BCRA y el padrón físico de ARCA. Aplicamos reglas de calidad de datos, unificamos la estructura de los CUIT/CUIL con `zfill()` e imprimimos métricas de resumen.

# %%
# ==========================================
# ⚙️ PASO 1: FIJANDO CEROS A LA IZQUIERDA (ZFILL) Y SUMMARY METRICS
# ==========================================
print("1. Cargando bases de datos en modo Lazy...")
df_bcra = pl.scan_parquet("/content/drive/MyDrive/Tesis2026/deudores_enero_2026_clasificados.parquet")
padron = pl.scan_parquet("/content/drive/MyDrive/Tesis2026/padron_fisicas.parquet")
entidades_maestro = pl.scan_csv("/content/drive/MyDrive/Tesis2026/EntidadesFinancierasBCRA.csv")

print("Estandarizando estructuras de IDs y Códigos con ceros a la izquierda...")
# 1.1 Blindar el BCRA: forzar strings limpios y aplicar zfill reglamentario
df_bcra = df_bcra.with_columns([
    pl.col("nro_id").cast(pl.Utf8).str.strip_chars().str.zfill(11),
    pl.col("cod_entidad").cast(pl.Utf8).str.strip_chars().str.zfill(5)
])

# 1.2 Blindar el Padrón de ARCA: CUITs obligatorios de 11 caracteres
padron = padron.with_columns([
    pl.col("cuit").cast(pl.Utf8).str.strip_chars().str.zfill(11),
    pl.col("fecha_fallecimiento").str.strip_chars().alias("fallecimiento_clean"),
    pl.col("fecha_nacimiento").str.strip_chars().alias("nacimiento_clean"),
    pl.col("sexo").str.strip_chars().alias("sexo_clean"),
    pl.col("provincia").cast(pl.Utf8).str.zfill(2)
])

# 1.3 Blindar el Maestro de Entidades: Códigos obligatorios de 5 caracteres
entidades_maestro = entidades_maestro.with_columns(
    pl.col("cod_entidad").cast(pl.Utf8).str.strip_chars().str.zfill(5)
)

print("Ejecutando cruce poblacional (BCRA + Padrón)...")
joined = df_bcra.join(padron, left_on="nro_id", right_on="cuit", how="left")

print("\n" + "="*55)
print("📊 SUMMARY METRICS: PASO 1 (CRUCE Y POBLACIÓN PURIFICADA)")
print("="*55)

metricas_join = joined.select([
    pl.len().alias("total_original"),
    pl.col("sexo_clean").is_not_null().sum().alias("conservados_join"),
    pl.col("sexo_clean").is_null().sum().alias("excluidos_no_padron"),
    (pl.col("nacimiento_clean") == "1901-01-01").sum().alias("fechas_inconsistentes"),
    ((pl.col("fallecimiento_clean") != "") & pl.col("fallecimiento_clean").is_not_null()).sum().alias("fallecidos_detectados"),
    (pl.col("sexo_clean") == "").sum().alias("sexo_vacio")
]).collect().to_pandas()

print(f"-> Total de registros originales BCRA: {metricas_join['total_original'][0]:,}")
print(f"-> Excluidos (Empresas / Sin Match de CUIT): {metricas_join['excluidos_no_padron'][0]:,}")
print(f"-> Conservados tras recuperar ceros iniciales: {metricas_join['conservados_join'][0]:,}")

print("\nAnomalías depuradas en los registros con match (Reglas ARCA):")
print(f"  - Fechas de nacimiento '1901-01-01' excluidas: {metricas_join['fechas_inconsistentes'][0]:,}")
print(f"  - Registros de personas fallecidas excluidos: {metricas_join['fallecidos_detectados'][0]:,}")
print(f"  - Género vacío excluido: {metricas_join['sexo_vacio'][0]:,}")

# Filtros sanitarios finales para el MCA (Mantenemos únicamente M y F de forma estricta)
base_limpia = joined.filter(
    pl.col("sexo_clean").is_in(['M', 'F'])
).filter(
    (pl.col("fallecimiento_clean") == "") | pl.col("fallecimiento_clean").is_null()
).filter(
    pl.col("nacimiento_clean") != "1901-01-01"
)

total_final = base_limpia.select(pl.len()).collect().item()
print(f"\n=> 🏆 POBLACIÓN ACTIVA FINAL CONSERVADA POST-ZFILL: {total_final:,} deudores físicos")
print("="*55 + "\n")

joined_con_nombres = base_limpia.join(entidades_maestro, on="cod_entidad", how="left")
# Out:
# 1. Cargando bases de datos en modo Lazy...
# Estandarizando estructuras de IDs y Códigos con ceros a la izquierda...
# Ejecutando cruce poblacional (BCRA + Padrón)...
#
# =======================================================
# 📊 SUMMARY METRICS: PASO 1 (CRUCE Y POBLACIÓN PURIFICADA)
# =======================================================
# -> Total de registros originales BCRA: 32,642,267
# -> Excluidos (Empresas / Sin Match de CUIT): 28,338,304
# -> Conservados tras recuperar ceros iniciales: 4,303,963
#
# Anomalías depuradas en los registros con match (Reglas ARCA):
#   - Fechas de nacimiento '1901-01-01' excluidas: 7,477
#   - Registros de personas fallecidas excluidos: 13,500
#   - Género vacío excluido: 39
#
# => 🏆 POBLACIÓN ACTIVA FINAL CONSERVADA POST-ZFILL: 4,282,848 deudores físicos
# =======================================================

# %% [markdown]
# ## <span style="color: #2b7a78;">3. Filtrado Top 20 y Macro-Regiones Geográficas 🗺️</span>
# Extraemos las 20 entidades con mayor volumen de deuda y segmentamos a los deudores en regiones macro utilizando el estándar del INDEC (AMBA, Región Pampeana, NOA, NEA, Cuyo, Patagonia).

# %%
# ==========================================
# 🏦 PASO 2: FILTRADO TOP 20 Y FEATURE ENGINEERING
# ==========================================
print("Calculando concentración de deuda para el Top 20...")

top_20_calculado = joined_con_nombres.group_by(["cod_entidad", "nombre_entidad", "grupo_entidad"]).agg(
    pl.col("deuda_total").sum().alias("volumen_deuda_total")
).sort("volumen_deuda_total", descending=True).limit(20)

df_top20_ranking = top_20_calculado.collect().to_pandas()

lista_codigos_top20 = df_top20_ranking["cod_entidad"].tolist()
base_filtrada_top20 = joined_con_nombres.filter(pl.col("cod_entidad").is_in(lista_codigos_top20))

# 3.1 Feature Engineering (Edades y Macro-Regiones Geográficas)
base_features = base_filtrada_top20.with_columns(
    pl.col("nacimiento_clean").str.strptime(pl.Date, "%Y-%m-%d", strict=False).alias("fecha_nac_dt"),
    pl.col("codigo_postal").cast(pl.Int32, strict=False).fill_null(0).alias("cp_num")
).with_columns(
    ((pl.date(2026, 1, 1) - pl.col("fecha_nac_dt")).dt.total_days() / 365.25).floor().alias("edad")
).with_columns([
    pl.when(pl.col("edad") <= 25).then(pl.lit("Jóvenes (18-25)"))
    .when(pl.col("edad") <= 40).then(pl.lit("Adultos en Inserción (26-40)"))
    .when(pl.col("edad") <= 65).then(pl.lit("Adultos Consolidados (41-65)"))
    .otherwise(pl.lit("Adultos Mayores (>65)")).alias("Edad"),

    # 🗺️ LÓGICA DE MACRO-REGIONES (INDEC + AMBA)
    pl.when((pl.col("cp_num") >= 1000) & (pl.col("cp_num") <= 1499)).then(pl.lit("AMBA - CABA"))
    .when((pl.col("cp_num") >= 1600) & (pl.col("cp_num") <= 1999)).then(pl.lit("AMBA - Conurbano"))
    .when(pl.col("provincia").is_in(["01", "03", "05", "11", "19"])).then(pl.lit("Región Pampeana"))
    .when(pl.col("provincia").is_in(["02", "06", "08", "12", "13", "23"])).then(pl.lit("NOA"))
    .when(pl.col("provincia").is_in(["04", "14", "16", "17"])).then(pl.lit("NEA"))
    .when(pl.col("provincia").is_in(["07", "09", "10"])).then(pl.lit("Cuyo"))
    .when(pl.col("provincia").is_in(["15", "18", "20", "21", "22"])).then(pl.lit("Patagonia"))
    .otherwise(pl.lit("Sin Especificar")).alias("Geografia")
]).select([
    pl.col("cod_entidad").alias("cod_entidad"),
    pl.col("nombre_entidad").alias("nombre_entidad"),
    pl.col("grupo_entidad").alias("grupo_entidad"),
    pl.col("segmento").alias("segmento"),
    pl.col("deuda_total").alias("deuda_total"),
    pl.col("sexo_clean").alias("sexo_clean"),
    pl.col("Edad"),
    pl.col("Geografia")
]).drop_nulls()

print("Materializando base consolidada...")
df_eda = base_features.collect().to_pandas()

print("\n" + "="*55)
print("📊 SUMMARY METRICS: UNIVERSO TOP 20 ENTIDADES (ARCA-BCRA)")
print("="*55)
print(f"Total de registros deudores en el Top 20: {len(df_eda):,}")
print(f"Total de deuda administrada por el Top 20: ${df_eda['deuda_total'].sum():,.2f}")
print("\nDistribución Geográfica:")
print(df_eda['Geografia'].value_counts(normalize=True).round(4) * 100)
print("="*55 + "\n")
# Out:
# Calculando concentración de deuda para el Top 20...
# Materializando base consolidada...
#
# =======================================================
# 📊 SUMMARY METRICS: UNIVERSO TOP 20 ENTIDADES (ARCA-BCRA)
# =======================================================
# Total de registros deudores en el Top 20: 3,329,896
# Total de deuda administrada por el Top 20: $8,868,904,858.00
#
# Distribución Geográfica:
# Geografia
# AMBA - Conurbano    26.26
# Región Pampeana     25.79
# NOA                 13.11
# AMBA - CABA         10.97
# NEA                  8.85
# Cuyo                 8.37
# Patagonia            5.63
# Sin Especificar      1.02
# Name: proportion, dtype: float64
# =======================================================

# %% [markdown]
# ## <span style="color: #2b7a78;">4. Visualizaciones Descriptivas del Mercado 📉</span>

# %%
# ==========================================
# 📈 PASO 3: BATERÍA DE GRÁFICOS EXPLORATORIOS
# ==========================================
print("Generando visualizaciones descriptivas...")

fig1 = px.bar(
    df_top20_ranking,
    x='volumen_deuda_total',
    y='nombre_entidad',
    color='grupo_entidad',
    orientation='h',
    title='1. Concentración de Deuda Total - Top 20 Entidades Financieras',
    labels={'volumen_deuda_total': 'Volumen de Deuda Acumulada ($)', 'nombre_entidad': 'Entidad Financiera', 'grupo_entidad': 'Grupo Institucional'},
    color_discrete_sequence=px.colors.qualitative.Dark24
)
fig1.update_layout(yaxis={'categoryorder':'total ascending'}, template='plotly_white', height=600)
fig1.show()

df_g4 = pd.crosstab(df_eda['grupo_entidad'], df_eda['Geografia'], normalize='index') * 100
fig4 = px.bar(
    df_g4.reset_index().melt(id_vars='grupo_entidad'),
    x='value', y='grupo_entidad', color='Geografia', orientation='h',
    title='2. Segmentación Geográfica de las Carteras por Grupo Institucional (%)',
    labels={'value': 'Porcentaje de la Cartera (%)', 'grupo_entidad': 'Grupo Institucional', 'Geografia': 'Región'},
    color_discrete_sequence=px.colors.qualitative.Safe
)
fig4.update_layout(template='plotly_white')
fig4.show()
# Out:
# Generando visualizaciones descriptivas...
# /usr/local/lib/python3.12/dist-packages/kaleido/_sync_server.py:11: UserWarning:
#
#
#
# Warning: You have Plotly version 5.24.1, which is not compatible with this version of Kaleido (1.3.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
# You can however, use the Kaleido API directly which will work with your plotly version. `kaleido.write_fig(...)`, for example. Please see the kaleido documentation.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="23f7963a-3674-469c-8dba-30bf4e12d448" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23f7963a-3674-469c-8dba-30bf4e12d448")) {                    Plotly.newPlot(                        "23f7963a-3674-469c-8dba-30bf4e12d448",                        [{"alignmentgroup":"True","hovertemplate":"Grupo Institucional=Banco\u003cbr\u003eVolumen de Deuda Acumulada ($)=%{x}\u003cbr\u003eEntidad Financiera=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Banco","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"Banco","offsetgroup":"Banco","orientation":"h","showlegend":true,"textposition":"auto","x":[1997086899.0,1054104908.0,941559027.0,807074098.0,764188715.0,683180010.0,290361949.0,283984168.0,236867997.0,198126486.0,146716728.0,141430446.0,110788894.0,89937191.0,63480226.0,63176287.0,56772273.0],"xaxis":"x","y":["BANCO DE LA NACION ARGENTINA","BANCO DE GALICIA Y BUENOS AIRES S.A.","BANCO SANTANDER ARGENTINA S.A.","BANCO DE LA PROVINCIA DE BUENOS AIRES","BANCO MACRO S.A.","BANCO BBVA ARGENTINA S.A.","BANCO DE LA PROVINCIA DE CORDOBA S.A.","INDUSTRIAL AND COMMERCIAL BANK OF CHINA (ARGENTINA) S.A.U.","BANCO DE LA CIUDAD DE BUENOS AIRES","BANCO SUPERVIELLE S.A.","BANCO PATAGONIA S.A.","NUEVO BANCO DE SANTA FE SOCIEDAD ANONIMA","BANCO CREDICOOP COOPERATIVO LIMITADO","BANCO HIPOTECARIO S.A.","NUEVO BANCO DE ENTRE RIOS S.A.","BANCO PROVINCIA DEL NEUQUEN SOCIEDAD ANONIMA","NUEVO BANCO DEL CHACO S. A."],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Grupo Institucional=Proveedor no Financiero\u003cbr\u003eVolumen de Deuda Acumulada ($)=%{x}\u003cbr\u003eEntidad Financiera=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Proveedor no Financiero","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Proveedor no Financiero","offsetgroup":"Proveedor no Financiero","orientation":"h","showlegend":true,"textposition":"auto","x":[551590960.0,262010555.0],"xaxis":"x","y":["TARJETA NARANJA S.A.","MERCADOLIBRE S.R.L."],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Grupo Institucional=Compania Financiera\u003cbr\u003eVolumen de Deuda Acumulada ($)=%{x}\u003cbr\u003eEntidad Financiera=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Compania Financiera","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Compania Financiera","offsetgroup":"Compania Financiera","orientation":"h","showlegend":true,"textposition":"auto","x":[126467041.0],"xaxis":"x","y":["NARANJA DIGITAL COMPANIA FINANCIERA S.A.U."],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="adfe64fe-afe3-4a91-9c38-6e31fcda2b1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adfe64fe-afe3-4a91-9c38-6e31fcda2b1c")) {                    Plotly.newPlot(                        "adfe64fe-afe3-4a91-9c38-6e31fcda2b1c",                        [{"alignmentgroup":"True","hovertemplate":"Región=AMBA - CABA\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AMBA - CABA","marker":{"color":"rgb(136, 204, 238)","pattern":{"shape":""}},"name":"AMBA - CABA","offsetgroup":"AMBA - CABA","orientation":"h","showlegend":true,"textposition":"auto","x":[14.460174793544448,2.453807863657512,6.33757622027451],"xaxis":"x","y":["Banco","Compania Financiera","Proveedor no Financiero"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Región=AMBA - Conurbano\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AMBA - Conurbano","marker":{"color":"rgb(204, 102, 119)","pattern":{"shape":""}},"name":"AMBA - Conurbano","offsetgroup":"AMBA - Conurbano","orientation":"h","showlegend":true,"textposition":"auto","x":[27.561733947906557,15.94274023416338,25.465572939760563],"xaxis":"x","y":["Banco","Compania Financiera","Proveedor no Financiero"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Región=Cuyo\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cuyo","marker":{"color":"rgb(221, 204, 119)","pattern":{"shape":""}},"name":"Cuyo","offsetgroup":"Cuyo","orientation":"h","showlegend":true,"textposition":"auto","x":[6.993718277809734,13.319396554471346,9.979896850506579],"xaxis":"x","y":["Banco","Compania Financiera","Proveedor no Financiero"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Región=NEA\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NEA","marker":{"color":"rgb(17, 119, 51)","pattern":{"shape":""}},"name":"NEA","offsetgroup":"NEA","orientation":"h","showlegend":true,"textposition":"auto","x":[6.879334679718323,15.901312309192539,11.165332568769108],"xaxis":"x","y":["Banco","Compania Financiera","Proveedor no Financiero"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Región=NOA\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NOA","marker":{"color":"rgb(51, 34, 136)","pattern":{"shape":""}},"name":"NOA","offsetgroup":"NOA","orientation":"h","showlegend":true,"textposition":"auto","x":[12.222928919488036,19.188140141109887,13.787159988398182],"xaxis":"x","y":["Banco","Compania Financiera","Proveedor no Financiero"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Región=Patagonia\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Patagonia","marker":{"color":"rgb(170, 68, 153)","pattern":{"shape":""}},"name":"Patagonia","offsetgroup":"Patagonia","orientation":"h","showlegend":true,"textposition":"auto","x":[4.370801521398145,7.585134385815079,7.439415508429654],"xaxis":"x","y":["Banco","Compania Financiera","Proveedor no Financiero"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Región=Región Pampeana\u003cbr\u003ePorcentaje de la Cartera (%)=%{x}\u003cbr\u003eGrupo Institucional=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Región Pampeana","marker":{"color":"r ...

# %% [markdown]
# ## <span style="color: #2b7a78;">5. Preprocesamiento de Masas y Análisis de Correspondencias Múltiples (MCA) 🧠</span>
# Extraemos una muestra representativa de 250k deudores y corremos el MCA tradicional para mapear los atributos individuales categóricos puros sin agrupar.

# %%
# ==========================================
# 🧠 PASO 4: PREPROCESAMIENTO Y MCA TRADICIONAL
# ==========================================
print("\n=======================================================")
print("🧮 DISTRIBUCIÓN DE MASAS (PREVIO AL FILTRADO)")
print("=======================================================")
for col in ['nombre_entidad', 'sexo_clean', 'Edad', 'Geografia']:
    print(f"--- {col} ---")
    distribucion = df_eda[col].value_counts(normalize=True) * 100
    print(distribucion.round(2).to_string(), "\n")

df_mca_limpio = df_eda[df_eda['sexo_clean'].isin(['M', 'F'])].copy()

X_mca = df_mca_limpio[['nombre_entidad', 'sexo_clean', 'Edad', 'Geografia']].copy()
X_mca.columns = ['Entidad', 'Genero', 'Edad', 'Geografia']

df_mca_sample = X_mca.sample(n=min(250000, len(X_mca)), random_state=42)

print("\nEntrenando modelo MCA...")
mca = prince.MCA(n_components=2, n_iter=10, random_state=42)
mca = mca.fit(df_mca_sample)

v1, v2 = mca.percentage_of_variance_[0], mca.percentage_of_variance_[1]
print(f"¡MCA Finalizado! Varianza retenida (Inercia cruda): Dim1={v1:.2f}% | Dim2={v2:.2f}%")

coords = mca.column_coordinates(df_mca_sample).copy()
coords.columns = ['Dim_1', 'Dim_2']
coords['Atributo_Original'] = coords.index

def limpiar_nombre(attr):
    prefijos = ['Entidad_', 'Edad_', 'Geografia_', 'Genero_']
    for p in prefijos:
        if str(attr).startswith(p): return str(attr).replace(p, '', 1)
    return str(attr)

def clasificar_variable(attr):
    attr_str = str(attr)
    if attr_str.startswith('Entidad_'): return 'Top 20 Bancos/Fintech'
    if attr_str.startswith('Edad_'): return 'Rango Etario'
    if attr_str.startswith('Geografia_'): return 'Región Geográfica'
    if attr_str.startswith('Genero_'): return 'Género'
    return 'Otro'

coords['Categoria'] = coords['Atributo_Original'].apply(limpiar_nombre)
coords['Tipo'] = coords['Atributo_Original'].apply(clasificar_variable)

fig5 = px.scatter(
    coords, x='Dim_1', y='Dim_2', color='Tipo', text='Categoria',
    title='Mapa Perceptual MCA - Top 20 Entidades y Atributos Demográficos',
    labels={'Dim_1': f"Dimensión 1 ({v1:.2f}%)", 'Dim_2': f"Dimensión 2 ({v2:.2f}%)"}
)
fig5.update_traces(textposition='top center', marker=dict(size=13, opacity=0.85, line=dict(width=1, color='DarkSlateGrey')))
fig5.update_layout(template='plotly_white', width=1300, height=850)
fig5.show()
# Out:
# =======================================================
# 🧮 DISTRIBUCIÓN DE MASAS (PREVIO AL FILTRADO)
# =======================================================
# --- nombre_entidad ---
# nombre_entidad
# MERCADOLIBRE S.R.L.                                           21.42
# TARJETA NARANJA S.A.                                          14.62
# BANCO DE LA NACION ARGENTINA                                   8.34
# BANCO DE GALICIA Y BUENOS AIRES S.A.                           7.73
# BANCO BBVA ARGENTINA S.A.                                      7.38
# BANCO MACRO S.A.                                               7.07
# BANCO DE LA PROVINCIA DE BUENOS AIRES                          6.80
# BANCO SANTANDER ARGENTINA S.A.                                 6.78
# NARANJA DIGITAL COMPANIA FINANCIERA S.A.U.                     4.71
# INDUSTRIAL AND COMMERCIAL BANK OF CHINA (ARGENTINA) S.A.U.     2.26
# BANCO PATAGONIA S.A.                                           1.98
# BANCO DE LA PROVINCIA DE CORDOBA S.A.                          1.96
# BANCO SUPERVIELLE S.A.                                         1.75
# NUEVO BANCO DE SANTA FE SOCIEDAD ANONIMA                       1.59
# BANCO DE LA CIUDAD DE BUENOS AIRES                             1.46
# BANCO CREDICOOP COOPERATIVO LIMITADO                           1.18
# BANCO HIPOTECARIO S.A.                                         0.93
# NUEVO BANCO DEL CHACO S. A.                                    0.80
# NUEVO BANCO DE ENTRE RIOS S.A.                                 0.77
# BANCO PROVINCIA DEL NEUQUEN SOCIEDAD ANONIMA                   0.47
#
# --- sexo_clean ---
# sexo_clean
# F    51.51
# M    48.49
#
# --- Edad ---
# Edad
# Adultos Consolidados (41-65)    46.37
# Adultos en Inserción (26-40)    33.56
# Adultos Mayores (>65)           13.04
# Jóvenes (18-25)                  7.04
#
# --- Geografia ---
# Geografia
# AMBA - Conurbano    26.26
# Región Pampeana     25.79
# NOA                 13.11
# AMBA - CABA         10.97
# NEA                  8.85
# Cuyo                 8.37
# Patagonia            5.63
# Sin Especificar      1.02
#
#
# Entrenando modelo MCA...
# ¡MCA Finalizado! Varianza retenida (Inercia cruda): Dim1=4.76% | Dim2=4.55%
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fb977709-bc71-4f58-bd08-54b7df7a5e19" class="plotly-graph-div" style="height:850px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb977709-bc71-4f58-bd08-54b7df7a5e19")) {                    Plotly.newPlot(                        "fb977709-bc71-4f58-bd08-54b7df7a5e19",                        [{"hovertemplate":"Tipo=Top 20 Bancos\u002fFintech\u003cbr\u003eDimensión 1 (4.76%)=%{x}\u003cbr\u003eDimensión 2 (4.55%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Top 20 Bancos\u002fFintech","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.85,"size":13},"mode":"markers+text","name":"Top 20 Bancos\u002fFintech","orientation":"v","showlegend":true,"text":["_BANCO BBVA ARGENTINA S.A.","_BANCO CREDICOOP COOPERATIVO LIMITADO","_BANCO DE GALICIA Y BUENOS AIRES S.A.","_BANCO DE LA CIUDAD DE BUENOS AIRES","_BANCO DE LA NACION ARGENTINA","_BANCO DE LA PROVINCIA DE BUENOS AIRES","_BANCO DE LA PROVINCIA DE CORDOBA S.A.","_BANCO HIPOTECARIO S.A.","_BANCO MACRO S.A.","_BANCO PATAGONIA S.A.","_BANCO PROVINCIA DEL NEUQUEN SOCIEDAD ANONIMA","_BANCO SANTANDER ARGENTINA S.A.","_BANCO SUPERVIELLE S.A.","_INDUSTRIAL AND COMMERCIAL BANK OF CHINA (ARGENTINA) S.A.U.","_MERCADOLIBRE S.R.L.","_NARANJA DIGITAL COMPANIA FINANCIERA S.A.U.","_NUEVO BANCO DE ENTRE RIOS S.A.","_NUEVO BANCO DE SANTA FE SOCIEDAD ANONIMA","_NUEVO BANCO DEL CHACO S. A.","_TARJETA NARANJA S.A."],"x":[-0.6885053546399439,-0.30691131155445006,-0.9064584764292587,-2.297127323850073,0.21961877659376705,-1.1178382395020618,-0.11429607952886124,0.31985878372629445,0.7431800772295868,0.07519461013404168,1.214969870254114,-0.7168462281504602,-0.6340173811987013,-0.8128743127988272,-0.041284262885217006,0.9172032542349815,-0.023876888773409502,2.775241604549554,2.8710131647911274,0.9010422787186944],"xaxis":"x","y":[0.45952730893661436,-0.5469130084474066,0.3259311399078962,0.6360805690683794,-0.5610563750872207,-0.9043697195688131,-2.948979055855114,-0.010838506026631351,-0.7546227381091964,0.516744165712696,3.9000861516770433,0.151227403083047,-0.7609836631867095,0.054553580886433056,0.6259427028212725,0.21654360849934098,-3.2208977412741797,-1.4656558949158796,2.0965427051196768,0.14032120250510818],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Tipo=Género\u003cbr\u003eDimensión 1 (4.76%)=%{x}\u003cbr\u003eDimensión 2 (4.55%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Género","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.85,"size":13},"mode":"markers+text","name":"Género","orientation":"v","showlegend":true,"text":["_F","_M"],"x":[0.08770044514595023,-0.09319682788987042],"xaxis":"x","y":[-0.09316643841615818,0.09900538716460398],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Tipo=Rango Etario\u003cbr\u003eDimensión 1 (4.76%)=%{x}\u003cbr\u003eDimensión 2 (4.55%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rango Etario","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.85,"size":13},"mode":"markers+text","name":"Rango Etario","orientation":"v","showlegend":true,"text":["_Adultos Consolidados (41-65)","_Adultos Mayores (\u003e65)","_Adultos en Inserción (26-40)","_Jóvenes (18-25)"],"x":[-0.043334079991712425,-0.03963635972220182,0.022119704319843798,0.2558162278252664],"xaxis":"x","y":[-0.053186641762453926,-1.0482818093385107,0.33752573699115285,0.6887280306569548],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Tipo=Región Geográfica\u003cbr\u0 ...

# %% [markdown]
# ## <span style="color: #2b7a78;">6. Comparación de MCA con Agrupamiento Estructural (Grupos BCRA) 📊</span>
# A continuación, aplicamos la segmentación de entidades propuesta (Fintech, Pública, Privada Nacional y Privada Extranjera) sobre el mapa del MCA. Esto nos ayuda a resolver el overplotting visual y ver cómo interactúan las ligas competitivas en el espacio demográfico.

# %%
# ==========================================
# 🚀 NUEVO ENFOQUE: MCA DIRECTO SOBRE LOS MACRO-GRUPOS
# ==========================================

# 1. Definimos el diccionario blindado (por si no lo tenías cargado en memoria)
grupos_bcra = {
    'MERCADOLIBRE': 'Fintech / No Bancario',
    'TARJETA NARANJA': 'Fintech / No Bancario',
    'NARANJA DIGITAL': 'Fintech / No Bancario',
    'BANCO DE LA NACION': 'Banca Pública / Mixta',
    'PROVINCIA DE BUENOS AIRES': 'Banca Pública / Mixta',
    'PROVINCIA DE CORDOBA': 'Banca Pública / Mixta',
    'CIUDAD DE BUENOS AIRES': 'Banca Pública / Mixta',
    'HIPOTECARIO': 'Banca Pública / Mixta',
    'CHACO': 'Banca Pública / Mixta',
    'NEUQUEN': 'Banca Pública / Mixta',
    'GALICIA': 'Banca Privada Nacional',
    'MACRO': 'Banca Privada Nacional',
    'PATAGONIA': 'Banca Privada Nacional',
    'SUPERVIELLE': 'Banca Privada Nacional',
    'SANTA FE': 'Banca Privada Nacional',
    'CREDICOOP': 'Banca Privada Nacional',
    'ENTRE RIOS': 'Banca Privada Nacional',
    'BBVA': 'Banca Privada Extranjera',
    'SANTANDER': 'Banca Privada Extranjera',
    'INDUSTRIAL AND COMMERCIAL': 'Banca Privada Extranjera'
}

# 2. Función para transformar la columna antes del MCA
def mapear_a_grupo(nombre):
    nombre_limpio = str(nombre).upper()
    for clave, grupo in grupos_bcra.items():
        if clave in nombre_limpio:
            return grupo
    return 'Otro'

# 3. Aplicamos el mapeo DIRECTAMENTE sobre el dataset base
df_mca_macro = df_eda[df_eda['sexo_clean'].isin(['M', 'F'])].copy()
df_mca_macro['Macro_Grupo'] = df_mca_macro['nombre_entidad'].apply(mapear_a_grupo)

# Nos quedamos solo con las columnas deseadas (reemplazando Entidad por Macro_Grupo)
X_macro = df_mca_macro[['Macro_Grupo', 'sexo_clean', 'Edad', 'Geografia']].copy()
X_macro.columns = ['Grupo_Entidad', 'Genero', 'Edad', 'Geografia']

print("Distribución real de deudores por Macro-Grupo:")
print(X_macro['Grupo_Entidad'].value_counts(normalize=True) * 100)

# 4. Muestreo Estratificado (manteniendo la proporción exacta de cada grupo)
fraccion_macro = min(250000 / len(X_macro), 1.0)
df_sample_macro = X_macro.groupby('Grupo_Entidad', group_keys=False).apply(lambda x: x.sample(frac=fraccion_macro, random_state=42))

# 5. Entrenamos el nuevo modelo MCA
print("\nEntrenando modelo MCA Macro...")
mca_macro = prince.MCA(n_components=2, n_iter=10, random_state=42)
mca_macro = mca_macro.fit(df_sample_macro)

v1_m = mca_macro.percentage_of_variance_[0]
v2_m = mca_macro.percentage_of_variance_[1]

# 6. Extracción de coordenadas y limpieza
coords_macro = mca_macro.column_coordinates(df_sample_macro).copy()
coords_macro.columns = ['Dim_1', 'Dim_2']
coords_macro['Atributo_Original'] = coords_macro.index

def clasificar_variable_macro(attr):
    if str(attr).startswith('Grupo_Entidad_'): return 'Modelo de Negocio'
    if str(attr).startswith('Edad_'): return 'Rango Etario'
    if str(attr).startswith('Geografia_'): return 'Región Geográfica'
    if str(attr).startswith('Genero_'): return 'Género'
    return 'Otro'

coords_macro['Categoria'] = coords_macro['Atributo_Original'].apply(lambda x: str(x).split('_', 1)[-1] if '_' in str(x) else x)
coords_macro['Tipo'] = coords_macro['Atributo_Original'].apply(clasificar_variable_macro)

# 7. Graficamos
fig_macro = px.scatter(
    coords_macro, x='Dim_1', y='Dim_2', color='Tipo', text='Categoria',
    title='Mapa Perceptual MCA - Análisis Macro-Estructural (Grupos BCRA)',
    labels={'Dim_1': f"Dimensión 1 ({v1_m:.2f}%)", 'Dim_2': f"Dimensión 2 ({v2_m:.2f}%)"},
    color_discrete_sequence=px.colors.qualitative.Bold
)

fig_macro.update_traces(
    textposition='top center',
    marker=dict(size=16, opacity=0.9, line=dict(width=1.5, color='DarkSlateGrey'))
)

fig_macro.update_layout(template='plotly_white', width=1300, height=850)
fig_macro.show()
# Out:
# Distribución real de deudores por Macro-Grupo:
# Grupo_Entidad
# Fintech / No Bancario       40.743345
# Banca Privada Nacional      22.084774
# Banca Pública / Mixta       20.755603
# Banca Privada Extranjera    16.416278
# Name: proportion, dtype: float64
# /tmp/ipykernel_24058/1588177644.py:50: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# Entrenando modelo MCA Macro...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4cabdd01-1b7b-43a1-93f6-20868624ef71" class="plotly-graph-div" style="height:850px; width:1300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cabdd01-1b7b-43a1-93f6-20868624ef71")) {                    Plotly.newPlot(                        "4cabdd01-1b7b-43a1-93f6-20868624ef71",                        [{"hovertemplate":"Tipo=Modelo de Negocio\u003cbr\u003eDimensión 1 (9.40%)=%{x}\u003cbr\u003eDimensión 2 (8.52%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Modelo de Negocio","marker":{"color":"rgb(127, 60, 141)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1.5},"opacity":0.9,"size":16},"mode":"markers+text","name":"Modelo de Negocio","orientation":"v","showlegend":true,"text":["Entidad__Banca Privada Extranjera","Entidad__Banca Privada Nacional","Entidad__Banca Pública \u002f Mixta","Entidad__Fintech \u002f No Bancario"],"x":[0.7045370766986994,0.4990042238126235,0.7356159319338862,-0.9291003402977801],"xaxis":"x","y":[1.4908310411468342,-0.1753202293791171,-0.9265551682386128,-0.03364875739258673],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Tipo=Género\u003cbr\u003eDimensión 1 (9.40%)=%{x}\u003cbr\u003eDimensión 2 (8.52%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Género","marker":{"color":"rgb(17, 165, 121)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1.5},"opacity":0.9,"size":16},"mode":"markers+text","name":"Género","orientation":"v","showlegend":true,"text":["_F","_M"],"x":[-0.0858169457910079,0.09148493222750388],"xaxis":"x","y":[-0.33143085333382416,0.35332100060039395],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Tipo=Rango Etario\u003cbr\u003eDimensión 1 (9.40%)=%{x}\u003cbr\u003eDimensión 2 (8.52%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rango Etario","marker":{"color":"rgb(57, 105, 172)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1.5},"opacity":0.9,"size":16},"mode":"markers+text","name":"Rango Etario","orientation":"v","showlegend":true,"text":["_Adultos Consolidados (41-65)","_Adultos Mayores (\u003e65)","_Adultos en Inserción (26-40)","_Jóvenes (18-25)"],"x":[0.20404550085439044,1.1764673358076976,-0.469849849801243,-1.2801305588716776],"xaxis":"x","y":[0.07109309780418793,-0.95467556035324,0.18818322818396935,0.4065962208721592],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Tipo=Región Geográfica\u003cbr\u003eDimensión 1 (9.40%)=%{x}\u003cbr\u003eDimensión 2 (8.52%)=%{y}\u003cbr\u003eCategoria=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Región Geográfica","marker":{"color":"rgb(242, 183, 1)","symbol":"circle","line":{"color":"DarkSlateGrey","width":1.5},"opacity":0.9,"size":16},"mode":"markers+text","name":"Región Geográfica","orientation":"v","showlegend":true,"text":["_AMBA - CABA","_AMBA - Conurbano","_Cuyo","_NEA","_NOA","_Patagonia","_Región Pampeana","_Sin Especificar"],"x":[1.2607984542194666,0.06739766022165632,-0.5502995756553056,-0.816035515999936,-0.30380431964612187,-0.8040970837667246,0.17650750298553802,0.1260112274733999],"xaxis":"x","y":[0.9659162913263337,0.5821123510621469,-0.1362134684822296,-0.2985093014753115,-0.042436196822581415,-0.2927003456319206,-0.8050969352263886,0.8769825802449308],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0 ...

# %% [markdown]
# ## <span style="color: #2b7a78;">7. Exportación del Grafo a HTML y Hosting Local 🚀</span>

# %%
archivo_html_original = "Mapa_MCA_Top20_Regiones.html"
archivo_html_agrupado = "Mapa_MCA_Agrupado_BCRA.html"

fig5.write_html(archivo_html_original)
fig_macro.write_html(archivo_html_agrupado)
print(f"¡Gráficos interactivos guardados: {archivo_html_original} y {archivo_html_agrupado}!")
# Out:
# ¡Gráficos interactivos guardados: Mapa_MCA_Top20_Regiones.html y Mapa_MCA_Agrupado_BCRA.html!

# %%
import threading
import http.server
import socketserver
import os
from google.colab import output

PORT = 8081
os.chdir('/content')

def iniciar_servidor():
    Handler = http.server.SimpleHTTPRequestHandler
    socketserver.TCPServer.allow_reuse_address = True
    with socketserver.TCPServer(("", PORT), Handler) as httpd:
        print(f"\n[INFO] Servidor web local en puerto {PORT}.")
        httpd.serve_forever()

threading.Thread(target=iniciar_servidor, daemon=True).start()
print("Generando enlaces seguros de visualización...")
output.serve_kernel_port_as_window(PORT, path='/Mapa_MCA_Top20_Regiones.html')
output.serve_kernel_port_as_window(PORT, path='/Mapa_MCA_Agrupado_BCRA.html')
# Out:
# Generando enlaces seguros de visualización...
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.
# Exception in thread Thread-6 (iniciar_servidor):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_24058/4161772068.py", line 13, in iniciar_servidor
#   File "/usr/lib/python3.12/socketserver.py", line 457, in __init__
#     self.server_bind()
#   File "/usr/lib/python3.12/socketserver.py", line 478, in server_bind
#     self.socket.bind(self.server_address)
# OSError: [Errno 98] Address already in use
